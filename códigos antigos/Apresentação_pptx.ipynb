# %%
import pandas as pd
import os
from pptx import Presentation
from pptx.util import Inches, Pt, Cm
from pptx.dml.color import RGBColor

# %%
artist = 'hernandesDiasLopes'
artista = "Hernandes Dias Lopes"

# %%
import pandas as pd
import os
from pptx import Presentation
from pptx.util import Inches, Pt, Cm
from pptx.dml.color import RGBColor

artist = 'hernandesDiasLopes'
artista = "Hernandes Dias Lopes"



prs = Presentation()

# SLIDE CAPA ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Definir o tamanho do slide para widescreen (16:9)
prs.slide_width = Inches(13.333)  # 13.333in é o equivalente a 16:9 em widescreen
prs.slide_height = Inches(7.5)  # Altura proporcional para o tamanho widescreen

# Caminho para a imagem de fundo do slide de capa
background_image_path = 'resources/Capa_1.png'

# Adicionar um slide de capa
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Adicionar a imagem de fundo
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto (título)
textbox_title = slide.shapes.add_textbox(Cm(2.73), Cm(10.32), Cm(17.99), Cm(2.32))
text_frame_title = textbox_title.text_frame
p_title = text_frame_title.paragraphs[0]
run_title = p_title.add_run()
run_title.text = "Report Mensal"

# Configuração da fonte do título
font_title = run_title.font
font_title.size = Pt(65)
font_title.bold = True
font_title.name = 'Poppins'
font_title.color.rgb = RGBColor(226, 252, 81)  # Cor do título em formato RGB hexadecimal

# Adicionar a segunda caixa de texto (subtítulo)
textbox_subtitle = slide.shapes.add_textbox(Cm(2.87), Cm(14.8), Cm(5.14), Cm(1.35))
text_frame_subtitle = textbox_subtitle.text_frame
p_subtitle = text_frame_subtitle.paragraphs[0]
run_subtitle = p_subtitle.add_run()
run_subtitle.text = mes_foco

# Configuração da fonte do subtítulo
font_subtitle = run_subtitle.font
font_subtitle.size = Pt(26)
font_subtitle.bold = True
font_subtitle.name = 'Poppins'
font_subtitle.color.rgb = RGBColor(255, 255, 255)  # Cor do subtítulo em formato RGB hexadecimal (#ffffff)

# Adicionar a caixa de artista
textbox_artist = slide.shapes.add_textbox(Cm(2.87), Cm(13.2), Cm(5.14), Cm(1.35))
text_frame_artist = textbox_artist.text_frame
p_artista = text_frame_artist.paragraphs[0]
run_artist = p_artista.add_run()
run_artist.text = artista

# Configuração da fonte do subtítulo
font_artist = run_artist.font
font_artist.size = Pt(33)
font_artist.bold = True
font_artist.name = 'Poppins'
font_artist.color.rgb = RGBColor(205, 155, 255)  # Cor do subtítulo em formato RGB hexadecimal (#ffffff)

# SLIDE INSTRUÇÕES ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide_detalhado = prs.slides.add_slide(slide_layout)

# Adicionar a imagem de fundo
background_image_path_detalhado = 'resources/Capa_2.png'
slide_detalhado.shapes.add_picture(background_image_path_detalhado, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar o título do novo slide
textbox_title_detalhado = slide_detalhado.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(15), Cm(1.8))
text_frame_title_detalhado = textbox_title_detalhado.text_frame
p_title_detalhado = text_frame_title_detalhado.paragraphs[0]
run_title_detalhado = p_title_detalhado.add_run()
run_title_detalhado.text = "Resumo Detalhado da Análise"
font_title_detalhado = run_title_detalhado.font
font_title_detalhado.size = Pt(30)
font_title_detalhado.bold = True
font_title_detalhado.name = 'Poppins'
font_title_detalhado.color.rgb = RGBColor(226, 252, 81)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide_detalhado.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em formato RGB hexadecimal

# Adicionar caixas de texto para cada tópico
topicos = [
    "- O texto sempre discute a variação do último mês em relação a média dos últimos 6 meses para entender tendências.",
    "- Os gráficos exibem números absolutos dos últimos 6 meses; use-os para contextualizar as mudanças recentes.",
    "- O Resumo da Análise traz um resumo básico do relatório, sem maiores detalhes.",
    "- Observe como cada métrica reflete o engajamento e o crescimento do seu canal.",
    "- Identifique áreas de melhoria analisando picos e quedas no desempenho."
]

altura_inicial = Cm(3.94)
for topico in topicos:
    textbox = slide_detalhado.shapes.add_textbox(Cm(1.9), altura_inicial, Cm(30.5), Cm(1))
    text_frame = textbox.text_frame
    text_frame.word_wrap = True
    text_frame.auto_size = True
    p = text_frame.add_paragraph()
    run = p.add_run()
    run.text = topico
    font = run.font
    font.size = Pt(18)
    font.name = 'Poppins'
    font.color.rgb = RGBColor(236, 236, 236)  # Cor do texto em preto
    altura_inicial += Cm(2)

# Adicionar a caixa de texto para o hiperlink
textbox_link = slide_detalhado.shapes.add_textbox(Cm(1.9), altura_inicial, Cm(30.5), Cm(2))
text_frame_link = textbox_link.text_frame
p_link = text_frame_link.add_paragraph()
run_link = p_link.add_run()
run_link.text = "Acesse o guia completo para detalhes sobre a interpretação de cada seção do relatório."
run_link.hyperlink.address = "https://1bigmedia.com.br/guia-detalhado-do-relatorio-de-performance-no-youtube/"
font_link = run_link.font
font_link.size = Pt(18)
font_link.name = 'Poppins'
font_link.color.rgb = RGBColor(0, 0, 255)  # Cor do texto em azul para destacar o link


# SLIDE RESUMO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path_1 = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path_1, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(11.36), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Resumo da Análise"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em formato RGB hexadecimal

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em formato RGB hexadecimal

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(30.5), Cm(13.25))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Resumo da Análise']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto


# SLIDE ANALISE INICIAL ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Análise Inicial'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Análise Inicial"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Análise Inicial']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Análise_Inicial.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

# SLIDE RELEVANCIA ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Relevância'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Relevância"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Relevância']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Relevancia.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

# SLIDE CONVERSÃO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Conversão'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Conversão"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Conversão']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Conversao.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

# SLIDE QUALIDADE ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Qualidade'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Qualidade"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Qualidade']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Qualidade.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

# SLIDE MONETIZAÇÃO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Monetização'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Monetização"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = 'Texto de Monetização'
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Monetizacao.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

#SLIDE CRESCIMENTO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Crescimento'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Crescimento"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Crescimento']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Crescimento.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

#SLIDE ORIGEM DO TRAFEGO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Origem do Trafego'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Origem do Tráfego"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Origem do Tráfego']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Origem_do_trafego.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

#SLIDE RECEITA ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Adicionar um novo slide para 'Receita'
slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(8.33), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Receita"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em azul escuro

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(113, 55, 248)  # Cor de preenchimento em roxo

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(9.38), Cm(9.49))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Receita']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

# Adicionar a imagem
image_path = f'dados_full/{artist}/plots/Receita.jpg'
slide.shapes.add_picture(image_path, Cm(11.74), Cm(4.42), width=Cm(21.69), height=Cm(11.84))

#SLIDE CONCLUSAO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path_1 = 'resources/template_pagina.png'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path_1, 0, 0, width=prs.slide_width, height=prs.slide_height)

# Adicionar a primeira caixa de texto do novo slide
textbox_first = slide.shapes.add_textbox(Cm(1.68), Cm(0.71), Cm(11.36), Cm(1.8))
text_frame_first = textbox_first.text_frame
p_first = text_frame_first.paragraphs[0]
run_first = p_first.add_run()
run_first.text = "Conclusão"
font_first = run_first.font
font_first.size = Pt(30)
font_first.bold = True
font_first.name = 'Poppins'
font_first.color.rgb = RGBColor(25, 46, 104)  # Cor do texto em formato RGB hexadecimal

# Adicionar a segunda caixa de texto do novo slide
textbox_second = slide.shapes.add_textbox(Cm(1.9), Cm(2.32), Cm(9.38), Cm(1.11))
text_frame_second = textbox_second.text_frame
p_second = text_frame_second.paragraphs[0]
run_second = p_second.add_run()
run_second.text = artista
font_second = run_second.font
font_second.size = Pt(20)
font_second.bold = True
font_second.name = 'Poppins'
font_second.color.rgb = RGBColor(255, 255, 255)  # Cor do texto em branco
# Definir cor de preenchimento da caixa de texto
fill = textbox_second.fill
fill.solid()
fill.fore_color.rgb = RGBColor(33, 33, 33)  # Cor de preenchimento em formato RGB hexadecimal

# Adicionar a terceira caixa de texto do novo slide
textbox_third = slide.shapes.add_textbox(Cm(1.9), Cm(3.94), Cm(30.5), Cm(13.25))
text_frame_third = textbox_third.text_frame
text_frame_third.word_wrap = True
text_frame_third.auto_size = True
p_third = text_frame_third.paragraphs[0]
run_third = p_third.add_run()
run_third.text = arquivo[arquivo['Tópicos'] == 'Conclusão e Recomendações']['Textos'].iloc[0]
font_third = run_third.font
font_third.size = Pt(16)
font_third.name = 'Poppins'
font_third.color.rgb = RGBColor(0, 0, 0)  # Cor do texto em preto

#SLIDE DUVIDAS ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path_1 = 'resources/duvidas.jpg'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path_1, 0, 0, width=prs.slide_width, height=prs.slide_height)

#SLIDE OBRIGADO ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

slide_layout = prs.slide_layouts[5]  # Escolhendo um layout de slide em branco
slide = prs.slides.add_slide(slide_layout)

# Caminho para a imagem de fundo do novo slide
background_image_path_1 = 'resources/obrigado.jpg'

# Adicionar a imagem de fundo do novo slide
slide.shapes.add_picture(background_image_path_1, 0, 0, width=prs.slide_width, height=prs.slide_height)


# Salvar a apresentação
prs.save(f'export_teste/Relatorio Mensal {artista}.pptx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/emotionstudios/Documents/Scripts/Novos mensais/Apresentação_pptx.ipynb Cell 3 line 4
#      <a href='vscode-notebook-cell:/Users/emotionstudios/Documents/Scripts/Novos%20mensais/Apresenta%C3%A7%C3%A3o_pptx.ipynb#W2sZmlsZQ%3D%3D?line=46'>47</a> p_subtitle = text_frame_subtitle.paragraphs[0]
#      <a href='vscode-notebook-cell:/Users/emotionstudios/Documents/Scripts/Novos%20mensais/Apresenta%C3%A7%C3%A3o_pptx.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a> run_subtitle = p_subtitle.add_run()
# ---> <a href='vscode-notebook-cell:/Users/emotionstudios/Documents/Scripts/Novos%20mensais/Apresenta%C3%A7%C3%A3o_pptx.ipynb#W2sZmlsZQ%3D%3D?line=48'>49</a> run_subtitle.text = mes_foco
#      <a href='vscode-notebook-cell:/Users/emotionstudios/Documents/Scripts/Novos%20mensais/Apresenta%C3%A7%C3%A3o_pptx.ipynb#W2sZmlsZQ%3D%3D?line=50'>51</a> # Configuração da fonte do subtítulo
#      <a href='vscode-notebook-cell:/Users/emotionstudios/Documents/Scripts/Novos%20mensais/Apresenta%C3%A7%C3%A3o_pptx.ipynb#W2sZmlsZQ%3D%3D?line=51'>52</a> font_subtitle = run_subtitle.font
#
# NameError: name 'mes_foco' is not defined

# %%
import json

def buscar_lista_artistas():
    # Carrega o dicionário de comparações do arquivo JSON
    with open('dados_full/comparacoes.json') as json_file:
        comparacoes = json.load(json_file)
    
    # Acesso a exports.txt para buscar o nome dos artistas
    with open('dados_full/exports.txt') as f:
        lines = f.readlines()
    
    # Limpa espaços em branco no final de cada linha
    lines = [i.rstrip() for i in lines]

    # Preparar a lista para armazenar os pares de artistas
    artistas_e_correspondentes = []

    # Buscar correspondência para cada artista
    for artista in lines:
        if artista in comparacoes:
            artistas_e_correspondentes.append((artista, comparacoes[artista]))
        else:
            print(f'Sem correspondência para: {artista}')

    return artistas_e_correspondentes


def run():
    lista_de_artistas = buscar_lista_artistas()
    
    for artista in lista_de_artistas:
        artist = artista[1]
        artista = artista[0]

if __name__ == "__main__":
    run()
# Out:
# Adventista Brasil adventistaBrasil
# Adventista Sudamerica adventistaSudamerica
# All About allAbout
# André Fernandes andreFernandes
# Automotor automotor
# Bia Figueiredo biaFigueiredo
# BrunetCast brunetCast
# Camila Barros camilaBarros
# Cassio Cortes cassioCortes
# Daystar Espanhol daystarEspanhol
# Deive Leonardo deiveLeonardo
# Flavio Gomes flavioGomes
# Formula Indy formulaIndy
# Grande Premio grandePremio
# Grande Premio 2 grandePremio2
# Hernandes Dias Lopes hernandesDiasLopes
# IGIPP IGIPP
# Itatiaia itatiaia
# Itatiaia Esporte itatiaiaEsporte
# O Tempo oTempo
# Rodrigo Silva rodrigoSilva
# Sabe Todo sabeTodo
# Tiago Brunet tiagoBrunet
# TV A Crítica tvACritica
